# %% [markdown]
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/olilamm/thinkgreen/blob/main/docs/examples/ipyleaflet.ipynb)

# %% [markdown]
# Import ipyleaflet

# %%
import ipyleaflet

# %% [markdown]
# Set the visibility controls for the map.

# %%
from ipyleaflet import Map, basemaps, basemap_to_tiles

m = Map(
    basemap = basemap_to_tiles(basemaps.OpenTopoMap),
    center=(55,55),
    zoom=4
)

m
# Out:
# Map(center=[55, 55], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…
